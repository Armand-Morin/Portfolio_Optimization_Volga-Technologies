# %%
from dash import *
import pandas as pd
import yfinance as yf
import plotly.express as px
from jupyter_dash import JupyterDash

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__) #,external_stylesheets=external_stylesheets)

app.layout = html.Div(children = [
    html.Div(children=[
        html.H1(children='Portfolio Management CentraleSupelec'),
        html.Label('Market to compare performances to'),
        dcc.Checklist([ '^GSPC', #S&P 500
             '^DJI', # Dow 30
             '^IXIC', # Nasdaq
             '^FCHI', # CAC40
           ],['^GSPC'],id = 'market_index'
        ),
        html.Label('Stocks equity'),
        dcc.Checklist(['SPY', "QQQ", "VGK", "SCZ", "EWJ", "EEM"],
                      value = ['SPY', "QQQ", "VGK", "SCZ", "EWJ", "EEM"],
                      id = 'eq_index'
        ),
        html.Label('Stocks finance'),
        dcc.Checklist(['TIP', "IEF", "TLT", "BWX"],
                      value = ['TIP', "IEF", "TLT", "BWX"],
                      id = 'fin_index'
        ),
        html.Label('Stocks comodity'),
        dcc.Checklist(['DBC', "GLD"],
                      value = ['DBC', "GLD"],
                      id = 'com_index'
        ),
        html.Label('Stocks real estate'),
        dcc.Checklist(['REM', "VNQ", "RWX"],
                      value = ['REM', "VNQ", "RWX"],
                      id = 're_index'),], 
                 style={'padding': 20, 'flex': 10}),
    
    html.Div(children=[
        html.Label('Cryptos'),
        dcc.Checklist(['BTC', 'ETH', 'AVAX',"USDT", "BNB"],
                      id = 'crypto_index'
        ),
        html.Label('Others'),
        dcc.Checklist(['TWTR', 'INTC', 'TSM',"VWUSX", "AMC"],
                      id = 'ot_index'
        ),
        html.Label('Range Simulation: Start Date / End Date'),
        html.Div([
            dcc.RangeSlider(2015, 2021, 1, count=1,
                            marks={i: str(i) for i in range(2015, 2021)},
                            value=[2016, 2020],id = 'range_date'
                           )
        ]),
        
        html.Br(),
        html.Label('Duration of Rebalencing'),
        dcc.RadioItems(['1 month', '3 months', '5 months'], '1 month', id = 'frame_time',),], 
             style={'padding': 20, 'flex': 1}),
    
    html.Div([
        dcc.Graph(id='stock_price'),],
        style={'display': 'inline-block'})
    ,],
    style={'display': 'flex', 'flex-direction': 'column'})



@app.callback(
    Output('stock_price', 'figure'),
    Input('market_index', 'value'),
    Input('eq_index', 'value'),
    Input('fin_index', 'value'),
    Input('com_index', 'value'),
    Input('re_index', 'value'),
    Input('crypto_index', 'value'),
    Input('range_date', 'value'),
)
def update_y_timeseries(market,eq,fin,com,re,crypto,date):
    start_date, end_date = date[0], date[1]
    
    all_stocks = pd.DataFrame()
    symbols = []
    for x in [market,eq, fin, com, re]:
        for y in x:
            symbols.append(y)
    start_date = str(start_date) + '-01-01'
    end_date = str(end_date) + '-01-01'
    
    for symbol in symbols:
        tmp_close = yf.download(symbol, 
                          start= start_date, 
                          end= end_date,
                          interval = "1d",
                          threads = True,
                          progress=False)['Adj Close']
        all_stocks = pd.concat([all_stocks, tmp_close], axis=1)

    all_stocks.columns = symbols
    fig = px.scatter(all_stocks, x = all_stocks.index, y = symbols)
    
    return fig


if __name__ == '__main__':
    app.run_server(debug = True, mode = 'inline')
# Out:
# /Users/armand_morin/opt/anaconda3/lib/python3.9/site-packages/jupyter_dash/jupyter_app.py:139: UserWarning:
#
# The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/pg/6ps7_5w931b_cmf3yj_q2nrw0000gn/T/ipykernel_25613/455747470.py in update_y_timeseries(
#     market=[],
#     eq=['SPY', 'QQQ', 'VGK', 'SCZ', 'EWJ', 'EEM'],
#     fin=['TIP', 'IEF', 'TLT', 'BWX'],
#     com=['DBC', 'GLD'],
#     re=['REM', 'VNQ', 'RWX'],
#     crypto=None,
#     date=[2017, 2019]
# )
#      92
#      93     for symbol in symbols:
# ---> 94         tmp_close = yf.download(symbol,
#         tmp_close = Date
# 2017-01-03    206.147537
# 2017-01-04    207.373932
# 2017-01-05    207.209198
# 2017-01-06    207.950592
# 2017-01-09    207.264145
#                  ...
# 2018-12-24    222.798965
# 2018-12-26    234.055862
# 2018-12-27    235.852783
# 2018-12-28    235.548569
# 2018-12-31    237.611679
# Name: Adj Close, Length: 502, dtype: float64
#         global yf.download = <function download at 0x7f867dcbbf70>
#         symbol = 'QQQ'
#         global start = undefined
#         start_date = '2017-01-01'
#         global end = undefined
#         end_date = '2019-01-01'
#         global interval = undefined
#         global threads = undefined
#         global progress = undefined
#      95                           start= start_date,
#      96                           end= end_date,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/multi.py in download(
#     tickers=['QQQ'],
#     start='2017-01-01',
#     end='2019-01-01',
#     actions=False,
#     threads=1,
#     group_by='column',
#     auto_adjust=False,
#     back_adjust=False,
#     progress=False,
#     period='max',
#     show_errors=True,
#     interval='1d',
#     prepost=False,
#     proxy=None,
#     rounding=False,
#     timeout=None,
#     **kwargs={}
# )
#     136     if len(tickers) == 1:
#     137         ticker = tickers[0]
# --> 138         return shared._DFS[shared._ISINS.get(ticker, ticker)]
#         global shared._DFS = {'QQQ':                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  119.269997  119.989998  118.889999  119.540001  115.292564
# 2017-01-04  119.669998  120.410004  119.660004  120.190002  115.919479
# 2017-01-05  120.099998  120.949997  120.099998  120.870003  116.575302
# 2017-01-06  121.000000  122.250000  120.690002  121.930000  117.597641
# 2017-01-09  122.029999  122.550003  121.949997  122.330002  117.983421
# ...                ...         ...         ...         ...         ...
# 2018-12-24  146.080002  147.979996  143.460007  143.500000  140.842865
# 2018-12-26  145.080002  152.539993  144.089996  152.460007  149.636963
# 2018-12-27  150.369995  153.179993  147.080002  153.050003  150.216034
# 2018-12-28  154.149994  155.589996  151.720001  152.970001  150.137497
# 2018-12-31  154.470001  154.979996  152.710007  154.259995  151.403580
#
#               Volume
# Date
# 2017-01-03  22307600
# 2017-01-04  19749100
# 2017-01-05  20644300
# 2017-01-06  24074300
# 2017-01-09  18909200
# ...              ...
# 2018-12-24  56163300
# 2018-12-26  98982100
# 2018-12-27  85824300
# 2018-12-28  77856600
# 2018-12-31  53015300
#
# [502 rows x 6 columns]}
#         global shared._ISINS.get = <built-in method get of dict object at 0x7f867ed78780>
#         ticker = 'QQQ'
#     139
#     140     try:
#
# KeyError: 'QQQ'
#
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/pg/6ps7_5w931b_cmf3yj_q2nrw0000gn/T/ipykernel_25613/455747470.py in update_y_timeseries(
#     market=[],
#     eq=['SPY', 'QQQ', 'VGK', 'SCZ', 'EWJ', 'EEM'],
#     fin=['TIP', 'IEF', 'TLT', 'BWX'],
#     com=['DBC', 'GLD'],
#     re=['REM', 'VNQ', 'RWX'],
#     crypto=None,
#     date=[2017, 2020]
# )
#      92
#      93     for symbol in symbols:
# ---> 94         tmp_close = yf.download(symbol,
#         tmp_close = Date
# 2017-01-03    43.843437
# 2017-01-04    44.324558
# 2017-01-05    44.718201
# 2017-01-06    44.613239
# 2017-01-09    44.543243
#                 ...
# 2019-12-24    58.856041
# 2019-12-26    59.218590
# 2019-12-27    59.514343
# 2019-12-30    59.094555
# 2019-12-31    59.418938
# Name: Adj Close, Length: 754, dtype: float64
#         global yf.download = <function download at 0x7f867dcbbf70>
#         symbol = 'EWJ'
#         global start = undefined
#         start_date = '2017-01-01'
#         global end = undefined
#         end_date = '2020-01-01'
#         global interval = undefined
#         global threads = undefined
#         global progress = undefined
#      95                           start= start_date,
#      96                           end= end_date,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/multi.py in download(
#     tickers=['EWJ'],
#     start='2017-01-01',
#     end='2020-01-01',
#     actions=False,
#     threads=1,
#     group_by='column',
#     auto_adjust=False,
#     back_adjust=False,
#     progress=False,
#     period='max',
#     show_errors=True,
#     interval='1d',
#     prepost=False,
#     proxy=None,
#     rounding=False,
#     timeout=None,
#     **kwargs={}
# )
#     136     if len(tickers) == 1:
#     137         ticker = tickers[0]
# --> 138         return shared._DFS[shared._ISINS.get(ticker, ticker)]
#         global shared._DFS = {'QQQ':                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  119.269997  119.989998  118.889999  119.540001  115.292564
# 2017-01-04  119.669998  120.410004  119.660004  120.190002  115.919479
# 2017-01-05  120.099998  120.949997  120.099998  120.870003  116.575302
# 2017-01-06  121.000000  122.250000  120.690002  121.930000  117.597641
# 2017-01-09  122.029999  122.550003  121.949997  122.330002  117.983421
# ...                ...         ...         ...         ...         ...
# 2018-12-24  146.080002  147.979996  143.460007  143.500000  140.842865
# 2018-12-26  145.080002  152.539993  144.089996  152.460007  149.636963
# 2018-12-27  150.369995  153.179993  147.080002  153.050003  150.216034
# 2018-12-28  154.149994  155.589996  151.720001  152.970001  150.137497
# 2018-12-31  154.470001  154.979996  152.710007  154.259995  151.403580
#
#               Volume
# Date
# 2017-01-03  22307600
# 2017-01-04  19749100
# 2017-01-05  20644300
# 2017-01-06  24074300
# 2017-01-09  18909200
# ...              ...
# 2018-12-24  56163300
# 2018-12-26  98982100
# 2018-12-27  85824300
# 2018-12-28  77856600
# 2018-12-31  53015300
#
# [502 rows x 6 columns], 'EWJ':                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-01-03  49.060001  49.290001  48.930000  49.259998  45.398899   9607300
# 2017-01-04  49.980000  50.279999  49.980000  50.250000  46.311306  10819600
# 2017-01-05  50.509998  50.639999  50.470001  50.540001  46.578579   7376100
# 2017-01-06  50.410000  50.560001  50.369999  50.459999  46.504845   3625700
# 2017-01-09  50.490002  50.520000  50.400002  50.509998  46.550919   4773200
# ...               ...        ...        ...        ...        ...       ...
# 2019-12-24  59.570000  59.619999  59.490002  59.529999  57.641788   3726900
# 2019-12-26  59.610001  59.709999  59.570000  59.689999  57.796711   3554300
# 2019-12-27  59.740002  59.790001  59.529999  59.580002  57.690201   3741900
# 2019-12-30  59.540001  59.549999  59.009998  59.049999  57.177010   6503200
# 2019-12-31  59.020000  59.259998  58.950001  59.240002  57.360989   5113900
#
# [754 rows x 6 columns]}
#         global shared._ISINS.get = <built-in method get of dict object at 0x7f867ed78780>
#         ticker = 'EWJ'
#     139
#     140     try:
#
# KeyError: 'EWJ'
